# %%
from google.colab import files
from google.colab import drive
import os

# optional: mount Google Drive
drive.mount('/content/gdrive')

# cd parth to Kaggle data
# %cd /content/gdrive/My Drive/Kaggle/melanoma
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/.shortcut-targets-by-id/1qJ47SkRrR6gtmKvnBstwgxcG-abjnb3a/Kaggle/melanoma

# %%
import tensorflow as tf
from skimage import io
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib

# %%
# Transformation
X = tf.range(10) # any data tensor
dataset = tf.data.Dataset.from_tensor_slices(X)
dataset = dataset.repeat(3).batch(7)

dataset.map(lambda x: x * 2)
dataset.apply(tf.data.experimental.unbatch())
dataset.filter(lambda x: x < 5)

# data retrieval
for item in dataset.take(3):
    print(item)
# Out:
# WARNING:tensorflow:From <ipython-input-7-b956fd9ac9a3>:7: unbatch (from tensorflow.python.data.experimental.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.unbatch()`.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b956fd9ac9a3> in <module>()
#       6 dataset.map(lambda x: x * 2)
#       7 dataset.apply(tf.data.experimental.unbatch())
# ----> 8 dataset.filter(lambda x: x < 5)
#       9
#      10 # data retrieval
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py in filter(self, predicate)
#    1778           `predicate` is `True`.
#    1779     """
# -> 1780     return FilterDataset(self, predicate)
#    1781
#    1782   def apply(self, transformation_func):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, predicate, use_legacy_function)
#    4237                    "boolean tensor. Was {}.").format(
#    4238                        wrapped_func.output_structure)
# -> 4239       raise ValueError(error_msg)
#    4240     self._predicate = wrapped_func
#    4241     variant_tensor = gen_dataset_ops.filter_dataset(
#
# ValueError: `predicate` return type must be convertible to a scalar boolean tensor. Was TensorSpec(shape=(None,), dtype=tf.bool, name=None).

# %%
print(tf.io.FixedLenFeature([], tf.string))
# Out:
# FixedLenFeature(shape=[], dtype=tf.string, default_value=None)
