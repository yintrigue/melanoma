# %% [markdown]
# # Kaggle API File Transfer
# - https://tinyurl.com/ybe5gol5
# - https://tinyurl.com/y79mpq34

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/Kaggle/melanoma

# %%
from google.colab import files
from google.colab import drive
import os

# optional: mount Google Drive
drive.mount('/content/gdrive')

# set current directory
# %cd /content/gdrive/My Drive/Kaggle/melanoma
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle/melanoma"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/My Drive/Kaggle/melanoma

# %%
# upload kaggle.json or any file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eeb9dd57-5796-4d91-8b04-c97642e2cb9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eeb9dd57-5796-4d91-8b04-c97642e2cb9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# download tfrec kaggle datasets
files_tfrec = [ 'tfrecords/test00-687.tfrec',
                'tfrecords/test01-687.tfrec',
                'tfrecords/test02-687.tfrec',
                'tfrecords/test03-687.tfrec',
                'tfrecords/test04-687.tfrec',
                'tfrecords/test05-687.tfrec',
                'tfrecords/test06-687.tfrec',
                'tfrecords/test07-687.tfrec',
                'tfrecords/test08-687.tfrec',
                'tfrecords/test09-687.tfrec',
                'tfrecords/test10-687.tfrec',
                'tfrecords/test11-687.tfrec',
                'tfrecords/test12-687.tfrec',
                'tfrecords/test13-687.tfrec',
                'tfrecords/test14-687.tfrec',
                'tfrecords/test15-677.tfrec',
                'tfrecords/train00-2071.tfrec',
                'tfrecords/train01-2071.tfrec',
                'tfrecords/train02-2071.tfrec',
                'tfrecords/train03-2071.tfrec',
                'tfrecords/train04-2071.tfrec',
                'tfrecords/train05-2071.tfrec',
                'tfrecords/train06-2071.tfrec',
                'tfrecords/train07-2071.tfrec',
                'tfrecords/train08-2071.tfrec',
                'tfrecords/train09-2071.tfrec',
                'tfrecords/train10-2071.tfrec',
                'tfrecords/train11-2071.tfrec',
                'tfrecords/train12-2071.tfrec',
                'tfrecords/train13-2071.tfrec',
                'tfrecords/train14-2071.tfrec',
                'tfrecords/train15-2061.tfrec' ]
for file_ in files_tfrec:
    folder = 'train'
    if 'test' in file_:
        folder = 'test'
    
    # !kaggle competitions download -c siim-isic-melanoma-classification -f $file_ -p $folder
# Out:
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found
# 404 - Not Found

# %%
# show avaliable storage 
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   32G   71G  31% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# shm             5.9G     0  5.9G   0% /dev/shm
# tmpfs           6.4G   12K  6.4G   1% /var/colab
# /dev/sda1       114G   34G   81G  29% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           108G   41G   68G  38% /content/gdrive
